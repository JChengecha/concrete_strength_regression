# %% [markdown]
# > Build a __regression model__ using the deep learning Keras library,
#     and then you will experiment with increasing the number of training epochs and changing number of hidden layers
#     and you will see how changing these parameters impacts the performance of the model.
#
# The breakdown will be:
#
# Part A: 5 marks
#
# Part B: 5 marks
#
# Part C: 5 marks
#
# Part D: 5 marks
#
# >Model the same data about concrete compressive strength:
# [data_](https://cocl.us/concrete_data)

# %% [markdown]
# ## Part A: Build a baseline Model
#
# Use the Keras library to build a neural network with the following:
#
# - One hidden layer of 10 nodes, and a ReLU activation function
#
# - Use the adam optimizer and the mean squared error  as the loss function.
#
# 1. Randomly split the data into a training and test sets by holding 30% of the data for testing. You can use the
# train_test_split
# helper function from Scikit-learn.
#
# 2. Train the model on the training data using 50 epochs.
#
# 3. Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. You can use the mean_squared_error function from Scikit-learn.
#
# 4. Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.
#
# 5. Report the mean and the standard deviation of the mean squared errors.

# %%
# import pandas and numpy libraries
import pandas as pd
import numpy as np

# %% [markdown]
# ### import data

# %%
#import from provided URL

url = r'https://cocl.us/concrete_data'
df =pd.read_csv(url)
df.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer
# 0   540.0                 0.0      0.0  162.0               2.5  \
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# ### 1. Split data

# %%
# split to predictors (X) and Target (y) variables

X = df[df.columns[df.columns!="Strength"]]
y = df['Strength']

# %%
# split the data to training and test sets randomly with a test size of 30%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=101)

print("Size of Sets\nX_train size:", X_train.shape[0],"\ny_train size:",y_train.shape[0],
      "\n\nX_test size:", X_test.shape[0],"\ny_test size:", y_test.shape[0])
# Out:
# Size of Sets
# X_train size: 721
# y_train size: 721
#
# X_test size: 309
# y_test size: 309

# %% [markdown]
# #### Get the number of predictors for the model

# %%
# number of predictors
no_pred = X.shape[1]
no_pred
# Out:
# 8

# %% [markdown]
# ##### Build the baseline model

# %%
#import keras library
import keras
#import packages
from keras.models import Sequential
from keras.layers import Dense,Input

# %%
def reg_model():
    #create regression model
    model = Sequential()
    model.add(Input(shape=(no_pred,)))
    model.add(Dense(50,activation='relu'))
    model.add(Dense(50,activation='relu'))
    model.add(Dense(1))

    # compile the model
    model.compile(optimizer='adam', loss = 'mean_squared_error')
    return model

# %% [markdown]
# ### 2. Train with 50 epochs

# %%
# fit the regression model 
model=reg_model()
model.fit(x= X_train ,y =y_train, epochs=50,verbose=0)

# %% [markdown]
# ### 3. Evaluate the model on the test data and compute the mean squared error

# %%
from sklearn.metrics import mean_squared_error
# evalutae using MSE
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 54.0465962881772

# %% [markdown]
# ### 4. create a list of 50 mean squared errors.

# %%
# Create a list of 50 MSEs 
mse_list =[]
# using a for loop for this task
for i in range(50):
    model=reg_model()
    model.fit(X_train,y_train,epochs=50,verbose=0)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_list.append(mse)
    print(f"\n\nIteration {i+1}, Mean Squared Error: {mse}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 1, Mean Squared Error: 50.75515831253314
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 2, Mean Squared Error: 49.842255823386395
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 3, Mean Squared Error: 50.17140312313064
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
#
# Iteration 4, Mean Squared Error: 59.46539330430616
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 5, Mean Squared Error: 73.40639174980222
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 6, Mean Squared Error: 52.86874861307732
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 7, Mean Squared Error: 45.80261988242409
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
#
# Iteration 8, Mean Squared Error: 75.49250935937117
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 9, Mean Squared Error: 63.38769309034982
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
#
# Iteration 10, Mean Squared Error: 59.99500360761787
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 11, Mean Squared Error: 74.79874733735306
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 12, Mean Squared Error: 73.93972711945969
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 13, Mean Squared Error: 54.69163253765848
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
#
# Iteration 14, Mean Squared Error: 59.48557893068152
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
#
# Iteration 15, Mean Squared Error: 83.42362909030349
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 16, Mean Squared Error: 51.25914496312775
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 17, Mean Squared Error: 51.216593740135146
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
#
#
# Iteration 18, Mean Squared Error: 84.28909370865362
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
#
# Iteration 19, Mean Squared Error: 69.26630873870758
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 20, Mean Squared Error: 67.87211094032966
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 21, Mean Squared Error: 60.810132531889
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 22, Mean Squared Error: 62.681646369935166
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 23, Mean Squared Error: 71.222363355008
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 24, Mean Squared Error: 52.258775783580454
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 25, Mean Squared Error: 80.091209656542
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 26, Mean Squared Error: 72.82949780981583
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 27, Mean Squared Error: 65.75977308293515
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
#
# Iteration 28, Mean Squared Error: 60.183574208949565
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
#
# Iteration 29, Mean Squared Error: 72.17361855488559
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 30, Mean Squared Error: 47.44274059519937
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 31, Mean Squared Error: 64.05390317743286
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
#
# Iteration 32, Mean Squared Error: 47.06736910359556
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 33, Mean Squared Error: 63.82741077814903
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
#
# Iteration 34, Mean Squared Error: 68.1370112992581
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
#
# Iteration 35, Mean Squared Error: 120.00588597077099
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 36, Mean Squared Error: 77.9194708125124
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
#
# Iteration 37, Mean Squared Error: 52.804371175908116
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 38, Mean Squared Error: 45.128034953006924
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#
#
# Iteration 39, Mean Squared Error: 45.452930712425996
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
#
# Iteration 40, Mean Squared Error: 61.886803552261256
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 41, Mean Squared Error: 48.489844182863635
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 42, Mean Squared Error: 71.95859560425782
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
#
# Iteration 43, Mean Squared Error: 68.47730296091746
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
#
# Iteration 44, Mean Squared Error: 70.26910471383327
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 45, Mean Squared Error: 52.52221318101127
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
#
# Iteration 46, Mean Squared Error: 54.31701886064777
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 47, Mean Squared Error: 77.02514961607322
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 48, Mean Squared Error: 72.07378563560691
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 49, Mean Squared Error: 47.93695808064251
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
#
# Iteration 50, Mean Squared Error: 67.54326027360867

# %% [markdown]
# ### 5. Report the mean and the standard deviation of the mean squared errors.

# %%
#from the list of mse, get the mean std and mean of squared errors
mean_mse = np.mean(mse_list)
std_mse = np.std(mse_list)
print(f"Mean of Mean Squared Errors: {mean_mse}")
print(f"Standard Deviation of Mean Squared Errors: {std_mse}")
# Out:
# Mean of Mean Squared Errors: 63.47559001131865
# Standard Deviation of Mean Squared Errors: 13.56583306718807

# %% [markdown]
# ## Part B. Normalize the data
# Repeat Part A but use a normalized version of the data.
# Recall that one way to normalize the data is by subtracting the mean from the individual predictors and dividing by the standard deviation.

# %%
# split to predictors (X) and Target (y) variables

X = df[df.columns[df.columns!="Strength"]]
y = df['Strength']

# %%
# Normalise the data
X_norm = (X - X.mean()) / X.std()
X_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147  \
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %%
# split the data to training and test sets randomly with a test size of 30%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_norm,y,test_size=0.3,random_state=101)

print("Size of Sets\nX_train size:", X_train.shape[0],"\ny_train size:",y_train.shape[0],
      "\n\nX_test size:", X_test.shape[0],"\ny_test size:", y_test.shape[0])
# Out:
# Size of Sets
# X_train size: 721
# y_train size: 721
#
# X_test size: 309
# y_test size: 309

# %%
def reg_model():
    #create regression model
    model = Sequential()
    model.add(Input(shape=(no_pred,)))
    model.add(Dense(50,activation='relu'))
    model.add(Dense(50,activation='relu'))
    model.add(Dense(1))

    # compile the model
    model.compile(optimizer='adam', loss = 'mean_squared_error')
    return model

# %%
# fit the regression model 
model=reg_model()
model.fit(x= X_train ,y =y_train, epochs=50,verbose=0)

# %%
from sklearn.metrics import mean_squared_error
# evalutae using MSE
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 123.34147215512438

# %%
# Create a list of 50 MSEs 
mse_list =[]
# using a for loop for this task
for i in range(50):
    model=reg_model()
    model.fit(X_train,y_train,epochs=50,verbose=0)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_list.append(mse)
    print(f"\n\nIteration {i+1}, Mean Squared Error: {mse}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 1, Mean Squared Error: 118.82151516862136
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 2, Mean Squared Error: 129.6048205847144
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 3, Mean Squared Error: 118.71603061843751
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 4, Mean Squared Error: 104.59646139046383
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 5, Mean Squared Error: 132.5114313290645
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 6, Mean Squared Error: 115.10014396557033
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 7, Mean Squared Error: 110.59549409326995
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
#
# Iteration 8, Mean Squared Error: 104.43382148258206
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 9, Mean Squared Error: 113.56521527162306
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 10, Mean Squared Error: 109.96441219531712
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 11, Mean Squared Error: 119.17810189280824
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 12, Mean Squared Error: 124.50214415460673
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
#
# Iteration 13, Mean Squared Error: 110.20492560953487
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 14, Mean Squared Error: 122.74153150854727
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
#
# Iteration 15, Mean Squared Error: 109.4212465305614
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 16, Mean Squared Error: 127.86366158430839
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
#
# Iteration 17, Mean Squared Error: 115.15766917029593
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 18, Mean Squared Error: 122.712591695258
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 19, Mean Squared Error: 126.08726704686296
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 20, Mean Squared Error: 122.60781359326036
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 21, Mean Squared Error: 118.00304508429055
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 22, Mean Squared Error: 116.02498829470935
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 23, Mean Squared Error: 111.45289136105714
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
#
# Iteration 24, Mean Squared Error: 102.89009878797569
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 25, Mean Squared Error: 107.93775490547269
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 26, Mean Squared Error: 121.89384124115078
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 27, Mean Squared Error: 126.10163474271879
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
#
# Iteration 28, Mean Squared Error: 109.73669741811443
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 29, Mean Squared Error: 133.80567004094755
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 30, Mean Squared Error: 122.1634702083991
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
#
# Iteration 31, Mean Squared Error: 98.06101598404402
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 32, Mean Squared Error: 124.22071855182554
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 33, Mean Squared Error: 126.44039176449076
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
#
# Iteration 34, Mean Squared Error: 129.3958104609434
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 35, Mean Squared Error: 107.01270281864375
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 36, Mean Squared Error: 113.77028983239806
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 37, Mean Squared Error: 110.51356189291606
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 38, Mean Squared Error: 124.74041030387625
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 39, Mean Squared Error: 123.46870063889487
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
#
# Iteration 40, Mean Squared Error: 110.20410857414659
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 41, Mean Squared Error: 124.20063482282593
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 42, Mean Squared Error: 110.07959011100237
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 43, Mean Squared Error: 122.43503619395273
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 44, Mean Squared Error: 124.71253327970685
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
#
# Iteration 45, Mean Squared Error: 122.50993192643128
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 46, Mean Squared Error: 122.1023018404155
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
#
# Iteration 47, Mean Squared Error: 123.39143597105026
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 48, Mean Squared Error: 116.03727991482181
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 49, Mean Squared Error: 108.2945299772978
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 50, Mean Squared Error: 127.23549645808986

# %%
#from the list of mse, get the mean std and mean of squared errors
mean_mse = np.mean(mse_list)
std_mse = np.std(mse_list)
print(f"Mean of Mean Squared Errors: {mean_mse}")
print(f"Standard Deviation of Mean Squared Errors: {std_mse}")
# Out:
# Mean of Mean Squared Errors: 117.94445744576639
# Standard Deviation of Mean Squared Errors: 8.304650964976304

# %% [markdown]
# **How does the mean of the mean squared errors compare to that from Step A?**

# %% [markdown]
#  * The mean of the squared errors (MSE) for Step B is higher than for Step A, indicating worse performance in terms of average squared error.
#
#  * The errors in Step A are more dispersed (higher standard deviation) than in Step B, where errors are more consistent (lower standard deviation).
# >In conclusion, Step A shows a better performance with a lower MSE but has more variability in the errors, while Step B has a higher MSE with less variability in the errors.

# %% [markdown]
# ## Part C. Increase the number of epochs
# Repeat Part B but use 100 epochs this time for training.

# %%
# split to predictors (X) and Target (y) variables

X = df[df.columns[df.columns!="Strength"]]
y = df['Strength']

# %%
# Normalise the data
X_norm = (X - X.mean()) / X.std()
X_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147  \
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %%
# split the data to training and test sets randomly with a test size of 30%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_norm,y,test_size=0.3,random_state=101)

print("Size of Sets\nX_train size:", X_train.shape[0],"\ny_train size:",y_train.shape[0],
      "\n\nX_test size:", X_test.shape[0],"\ny_test size:", y_test.shape[0])
# Out:
# Size of Sets
# X_train size: 721
# y_train size: 721
#
# X_test size: 309
# y_test size: 309

# %%
def reg_model():
    #create regression model
    model = Sequential()
    model.add(Input(shape=(no_pred,)))
    model.add(Dense(50,activation='relu'))
    model.add(Dense(50,activation='relu'))
    model.add(Dense(1))

    # compile the model
    model.compile(optimizer='adam', loss = 'mean_squared_error')
    return model

# %%
# Create a list of 50 MSEs 
mse_list =[]
# using a for loop for this task
for i in range(50):
    model=reg_model()
    model.fit(X_train,y_train,epochs=100,verbose=0)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_list.append(mse)
    print(f"\n\nIteration {i+1}, Mean Squared Error: {mse}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 1, Mean Squared Error: 46.61291236097073
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
#
# Iteration 2, Mean Squared Error: 47.076283659060756
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
#
# Iteration 3, Mean Squared Error: 46.757999946957476
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
#
# Iteration 4, Mean Squared Error: 46.031332427152634
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 5, Mean Squared Error: 48.122504599005765
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 6, Mean Squared Error: 46.01635117466323
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 7, Mean Squared Error: 50.84267878949098
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
#
# Iteration 8, Mean Squared Error: 44.82560063676471
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
#
# Iteration 9, Mean Squared Error: 46.69922443492271
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
#
# Iteration 10, Mean Squared Error: 46.16818817057824
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 11, Mean Squared Error: 47.91713206151686
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 12, Mean Squared Error: 46.69348112046064
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 13, Mean Squared Error: 46.94284314284145
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
#
# Iteration 14, Mean Squared Error: 45.832845543542184
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 15, Mean Squared Error: 45.406227518893886
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
#
# Iteration 16, Mean Squared Error: 46.075501819944776
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 17, Mean Squared Error: 47.38763872397749
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 18, Mean Squared Error: 51.17410043290212
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 19, Mean Squared Error: 45.66849618364865
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 20, Mean Squared Error: 45.286525980489415
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 21, Mean Squared Error: 47.3136537454762
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
#
# Iteration 22, Mean Squared Error: 45.95365660338591
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 23, Mean Squared Error: 48.10812986424435
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 24, Mean Squared Error: 44.15683527081101
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
#
# Iteration 25, Mean Squared Error: 44.02536777291758
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 26, Mean Squared Error: 50.56743145807513
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 27, Mean Squared Error: 49.30891233626362
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 28, Mean Squared Error: 46.289569253304414
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 29, Mean Squared Error: 50.1421584362161
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 30, Mean Squared Error: 48.83797909652504
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 31, Mean Squared Error: 44.32221640937479
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 32, Mean Squared Error: 46.49673077326833
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 33, Mean Squared Error: 49.829001328162555
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 34, Mean Squared Error: 49.230625294126654
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 35, Mean Squared Error: 47.83872918390149
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 36, Mean Squared Error: 50.89927403595629
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 37, Mean Squared Error: 45.236114178412514
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 38, Mean Squared Error: 48.94043982109167
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
#
# Iteration 39, Mean Squared Error: 46.06636087137354
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 40, Mean Squared Error: 50.791236523247484
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 41, Mean Squared Error: 52.48343241362447
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 42, Mean Squared Error: 41.33167783771219
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 43, Mean Squared Error: 44.393675317908084
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 44, Mean Squared Error: 46.93436223995258
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 45, Mean Squared Error: 51.822712871714884
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 46, Mean Squared Error: 46.147850305478194
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 47, Mean Squared Error: 45.27168679048466
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 48, Mean Squared Error: 42.39323075123794
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
#
# Iteration 49, Mean Squared Error: 43.21644685527371
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 50, Mean Squared Error: 51.62928240625309

# %%
#from the list of mse, get the mean std and mean of squared errors
mean_mse = np.mean(mse_list)
std_mse = np.std(mse_list)
print(f"Mean of Mean Squared Errors: {mean_mse}")
print(f"Standard Deviation of Mean Squared Errors: {std_mse}")
# Out:
# Mean of Mean Squared Errors: 47.15033297547117
# Standard Deviation of Mean Squared Errors: 2.5021523771063805

# %% [markdown]
# **How does the mean of the mean squared errors compare to that from Step B**

# %% [markdown]
# * The mean MSE in Step C (47.15) is significantly lower than in Step B (117.94). This indicates that, on average, the squared errors are much smaller in Step C, suggesting better model performance.
#
# * The standard deviation of MSE in Step C (2.50) is also lower than in Step B (8.30). This suggests that the MSEs are more consistent (less variable) in Step C compared to Step B.
#
# > Step C outperforms Step B significantly in terms of both the average performance (lower mean MSE) and the consistency of the performance (lower standard deviation of MSE).

# %% [markdown]
# ## Part D. Increase the number of hidden layers
#
# Repeat part B but use a neural network with the following instead:
#
# - Three hidden layers, each of 10 nodes and ReLU activation function.

# %%
# split to predictors (X) and Target (y) variables

X = df[df.columns[df.columns!="Strength"]]
y = df['Strength']

# %%
# split the data to training and test sets randomly with a test size of 30%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_norm,y,test_size=0.3,random_state=101)

print("Size of Sets\nX_train size:", X_train.shape[0],"\ny_train size:",y_train.shape[0],
      "\n\nX_test size:", X_test.shape[0],"\ny_test size:", y_test.shape[0])
# Out:
# Size of Sets
# X_train size: 721
# y_train size: 721
#
# X_test size: 309
# y_test size: 309

# %%
# Normalise the data
X_norm = (X - X.mean()) / X.std()
X_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147  \
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %%
def reg_model():
    #create regression model
    model = Sequential()
    model.add(Input(shape=(no_pred,)))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(1))

    # compile the model
    model.compile(optimizer='adam', loss = 'mean_squared_error')
    return model

# %%
# Create a list of 50 MSEs 
mse_list =[]
# using a for loop for this task
for i in range(50):
    model=reg_model()
    model.fit(X_train,y_train,epochs=50,verbose=0)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_list.append(mse)
    print(f"\n\nIteration {i+1}, Mean Squared Error: {mse}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 1, Mean Squared Error: 141.28841290803803
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 2, Mean Squared Error: 131.58813263838448
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
#
# Iteration 3, Mean Squared Error: 151.82446079369896
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 4, Mean Squared Error: 153.70577264818087
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 5, Mean Squared Error: 158.6691970902952
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
#
# Iteration 6, Mean Squared Error: 151.75469542770443
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 7, Mean Squared Error: 147.74788300439366
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
#
# Iteration 8, Mean Squared Error: 158.18475227542586
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 9, Mean Squared Error: 141.7304079340366
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
#
# Iteration 10, Mean Squared Error: 143.21346238425312
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
#
# Iteration 11, Mean Squared Error: 126.81471896294462
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
#
# Iteration 12, Mean Squared Error: 146.43068089437003
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
#
# Iteration 13, Mean Squared Error: 154.21405437461087
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
#
# Iteration 14, Mean Squared Error: 147.53219195578424
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
#
# Iteration 15, Mean Squared Error: 106.16071268167093
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
#
# Iteration 16, Mean Squared Error: 137.20595665247234
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 17, Mean Squared Error: 149.6399888937244
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
#
# Iteration 18, Mean Squared Error: 150.82341372808534
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
#
# Iteration 19, Mean Squared Error: 156.96014635877395
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
#
# Iteration 20, Mean Squared Error: 154.46101109835791
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
#
# Iteration 21, Mean Squared Error: 145.94680179334756
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
#
# Iteration 22, Mean Squared Error: 99.78174960740103
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
#
# Iteration 23, Mean Squared Error: 144.9957247634479
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 24, Mean Squared Error: 119.52470097044595
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 25, Mean Squared Error: 154.91077614267934
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
#
# Iteration 26, Mean Squared Error: 132.70620099946345
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
#
# Iteration 27, Mean Squared Error: 131.36017345588863
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
#
# Iteration 28, Mean Squared Error: 138.55599521079367
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 29, Mean Squared Error: 138.41520823834918
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
#
# Iteration 30, Mean Squared Error: 121.57378643380254
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 31, Mean Squared Error: 156.9425098694737
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 32, Mean Squared Error: 153.93191473250326
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
#
# Iteration 33, Mean Squared Error: 144.11242749489395
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
#
# Iteration 34, Mean Squared Error: 148.32768769152864
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
#
# Iteration 35, Mean Squared Error: 137.45750766503355
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
#
# Iteration 36, Mean Squared Error: 147.64992812619312
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
#
#
# Iteration 37, Mean Squared Error: 103.33001419131948
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
#
# Iteration 38, Mean Squared Error: 124.44607215072179
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 39, Mean Squared Error: 153.48796193026374
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
#
# Iteration 40, Mean Squared Error: 135.46623217084903
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
#
# Iteration 41, Mean Squared Error: 146.1610182187466
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 42, Mean Squared Error: 149.19435778671843
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
#
# Iteration 43, Mean Squared Error: 146.74182756310606
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 44, Mean Squared Error: 142.79950064387484
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
#
# Iteration 45, Mean Squared Error: 141.34959005225045
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
#
# Iteration 46, Mean Squared Error: 104.18911969537463
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
#
# Iteration 47, Mean Squared Error: 151.15304446525047
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
#
# Iteration 48, Mean Squared Error: 156.94681537053242
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
#
# Iteration 49, Mean Squared Error: 146.89317520875377
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
#
# Iteration 50, Mean Squared Error: 151.41579795561083

# %%
#from the list of mse, get the mean std and mean of squared errors
mean_mse = np.mean(mse_list)
std_mse = np.std(mse_list)
print(f"Mean of Mean Squared Errors: {mean_mse}")
print(f"Standard Deviation of Mean Squared Errors: {std_mse}")
# Out:
# Mean of Mean Squared Errors: 141.59435346607648
# Standard Deviation of Mean Squared Errors: 14.669533346464172

# %% [markdown]
# **How does the mean of the mean squared errors compare to that from Step B?**

# %% [markdown]
# * Part D shows worse performance in terms of the mean MSE compared to Part B, with a higher mean MSE indicating larger average squared errors.
# * The higher standard deviation of MSE in Part D also indicates that the errors are more variable compared to Part B, suggesting less consistency in the squared errors.
# > Part B performs better than Part D in terms of both the average performance (lower mean MSE) and the consistency of the performance (lower standard deviation of MSE).
